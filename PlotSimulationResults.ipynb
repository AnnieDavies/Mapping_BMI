# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
fp = "\\SimulationData\\"
df_fromZ_low = pd.read_csv(fp + "FromZ_IOTF_SDlow.csv")
df_fromB_low = pd.read_csv(fp + "FromB_IOTF_SDlow.csv")
df_fromZ_mid = pd.read_csv(fp + "FromZ_IOTF_SDmid.csv")
df_fromB_mid = pd.read_csv(fp + "FromB_IOTF_SDmid.csv")
df_fromZ_high = pd.read_csv(fp + "FromZ_IOTF_SDhigh.csv")
df_fromB_high = pd.read_csv(fp + "FromB_IOTF_SDhigh.csv")

# %%
# Set Matplotlib to use LaTeX
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'

# Plotting

# Increase plot size
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))  # 1 row, 2 columns


# Plotting
line1 = axes[0].plot(df_fromZ_low['MeanZ'], df_fromZ_low['MeanZ'], color='black', marker='', linestyle='-', label='_nolegend_')
line2 = axes[0].scatter(df_fromZ_low['MeanZ'], df_fromZ_low['EstMeanZ_p_cdf'], color='green', marker='o', s=15, label="Analytical")
line3 = axes[0].scatter(df_fromZ_low['MeanZ'], df_fromZ_low['EstMeanZ_p_samp'], color='deepskyblue', marker='o', s=15, label="Sampling")
line4 = axes[0].scatter(df_fromZ_low['MeanZ'], df_fromZ_low['EstMeanZ_p_opt_samp'], color='red', marker='o', s=15, label="Optimization")
line5 = axes[0].scatter(df_fromZ_low['MeanZ'], df_fromZ_low['NaiveP'], color='darkviolet', marker='o', s=15, label="Naive")

# Set labels and limits
axes[0].set_xlabel("Simulated mean zBMI", fontsize = 18)
axes[0].set_ylabel("Estimated mean zBMI", fontsize = 18)
#axes[0].set_xlim(-0.25, 1.75)
#axes[0].set_ylim(-0.5, 2.5)

# Increase tick label font size for both x and y axes
axes[0].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[0].legend(handles=[line2, line3, line4, line5],loc="upper left", fontsize = 16)

## PLOT 2
                      
# Plotting
line1 = axes[1].plot(df_fromZ_low['SDZ'], df_fromZ_low['SDZ'], color='black', marker='', linestyle='-', label='_nolegend_')
line2 = axes[1].scatter(df_fromZ_low['SDZ'], df_fromZ_low['EstSDZ_p_cdf'], color='green', marker='o', s=15, label="Analytical")
line3 = axes[1].scatter(df_fromZ_low['SDZ'], df_fromZ_low['EstSDZ_p_samp'], color='deepskyblue', marker='o', s=15, label="Sampling")
line4 = axes[1].scatter(df_fromZ_low['SDZ'], df_fromZ_low['EstSDZ_p_opt_samp'], color='red', marker='o', s=15, label="Optimization")
    
# Set labels and limits
axes[1].set_xlabel("Simulated SD zBMI", fontsize = 18)
axes[1].set_ylabel("Estimated SD zBMI", fontsize = 18)
#axes[1].set_xlim(0.2, 2.3)
#axes[1].set_ylim(0.2, 2.3)

# Increase tick label font size for both x and y axes

axes[1].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[1].legend(handles=[line2, line3, line4],loc="upper left", fontsize = 16)


# Adjust layout to prevent overlapping
plt.tight_layout()

# Save the plot to a file (e.g., PNG format)
#plt.savefig('\\Supplement\\Sim_PtoZ_SDlow.png', dpi=300)

# Show the plot
#plt.show()
#display(fig)

# %%
# Set Matplotlib to use LaTeX
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'

# Plotting

# Increase plot size
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))  # 1 row, 2 columns


# Plotting
line1 = axes[0].plot(df_fromZ_mid['MeanZ'], df_fromZ_mid['MeanZ'], color='black', marker='', linestyle='-', label='_nolegend_')
line2 = axes[0].scatter(df_fromZ_mid['MeanZ'], df_fromZ_mid['EstMeanZ_p_cdf'], color='green', marker='o', s=15, label="Analytical")
line3 = axes[0].scatter(df_fromZ_mid['MeanZ'], df_fromZ_mid['EstMeanZ_p_samp'], color='deepskyblue', marker='o', s=15, label="Sampling")
line4 = axes[0].scatter(df_fromZ_mid['MeanZ'], df_fromZ_mid['EstMeanZ_p_opt_samp'], color='red', marker='o', s=15, label="Optimization")
line5 = axes[0].scatter(df_fromZ_mid['MeanZ'], df_fromZ_mid['NaiveP'], color='darkviolet', marker='o', s=15, label="Naive")

# Set labels and limits
axes[0].set_xlabel("Simulated mean zBMI", fontsize = 18)
axes[0].set_ylabel("Estimated mean zBMI", fontsize = 18)
#axes[0].set_xlim(-0.25, 1.75)
#axes[0].set_ylim(-0.5, 2.5)

# Increase tick label font size for both x and y axes
axes[0].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[0].legend(handles=[line2, line3, line4, line5],loc="upper left", fontsize = 16)

## PLOT 2
                      
# Plotting
line1 = axes[1].plot(df_fromZ_mid['SDZ'], df_fromZ_mid['SDZ'], color='black', marker='', linestyle='-', label='_nolegend_')
line2 = axes[1].scatter(df_fromZ_mid['SDZ'], df_fromZ_mid['EstSDZ_p_cdf'], color='green', marker='o', s=15, label="Analytical")
line3 = axes[1].scatter(df_fromZ_mid['SDZ'], df_fromZ_mid['EstSDZ_p_samp'], color='deepskyblue', marker='o', s=15, label="Sampling")
line4 = axes[1].scatter(df_fromZ_mid['SDZ'], df_fromZ_mid['EstSDZ_p_opt_samp'], color='red', marker='o', s=15, label="Optimization")
    
# Set labels and limits
axes[1].set_xlabel("Simulated SD zBMI", fontsize = 18)
axes[1].set_ylabel("Estimated SD zBMI", fontsize = 18)
#axes[1].set_xlim(0.2, 2.3)
#axes[1].set_ylim(0.2, 2.3)

# Increase tick label font size for both x and y axes

axes[1].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[1].legend(handles=[line2, line3, line4],loc="upper left", fontsize = 16)


# Adjust layout to prevent overlapping
plt.tight_layout()

# Save the plot to a file (e.g., PNG format)
#plt.savefig('\\Main\\Sim_PtoZ_SDmid.png', dpi=300)

# Show the plot
#plt.show()
#display(fig)

# %%
# Set Matplotlib to use LaTeX
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'

# Plotting

# Increase plot size
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))  # 1 row, 2 columns


# Plotting
line1 = axes[0].plot(df_fromZ_high['MeanZ'], df_fromZ_high['MeanZ'], color='black', marker='', linestyle='-', label='_nolegend_')
line2 = axes[0].scatter(df_fromZ_high['MeanZ'], df_fromZ_high['EstMeanZ_p_cdf'], color='green', marker='o', s=15, label="Analytical")
line3 = axes[0].scatter(df_fromZ_high['MeanZ'], df_fromZ_high['EstMeanZ_p_samp'], color='deepskyblue', marker='o', s=15, label="Sampling")
line4 = axes[0].scatter(df_fromZ_high['MeanZ'], df_fromZ_high['EstMeanZ_p_opt_samp'], color='red', marker='o', s=15, label="Optimization")
line5 = axes[0].scatter(df_fromZ_high['MeanZ'], df_fromZ_high['NaiveP'], color='darkviolet', marker='o', s=15, label="Naive")

# Set labels and limits
axes[0].set_xlabel("Simulated mean zBMI", fontsize = 18)
axes[0].set_ylabel("Estimated mean zBMI", fontsize = 18)
#axes[0].set_xlim(-0.25, 1.75)
#axes[0].set_ylim(-0.5, 2.5)

# Increase tick label font size for both x and y axes
axes[0].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[0].legend(handles=[line2, line3, line4, line5],loc="upper left", fontsize = 16)

## PLOT 2
                      
# Plotting
line1 = axes[1].plot(df_fromZ_high['SDZ'], df_fromZ_high['SDZ'], color='black', marker='', linestyle='-', label='_nolegend_')
line2 = axes[1].scatter(df_fromZ_high['SDZ'], df_fromZ_high['EstSDZ_p_cdf'], color='green', marker='o', s=15, label="Analytical")
line3 = axes[1].scatter(df_fromZ_high['SDZ'], df_fromZ_high['EstSDZ_p_samp'], color='deepskyblue', marker='o', s=15, label="Sampling")
line4 = axes[1].scatter(df_fromZ_high['SDZ'], df_fromZ_high['EstSDZ_p_opt_samp'], color='red', marker='o', s=15, label="Optimization")
    
# Set labels and limits
axes[1].set_xlabel("Simulated SD zBMI", fontsize = 18)
axes[1].set_ylabel("Estimated SD zBMI", fontsize = 18)
#axes[1].set_xlim(0.2, 2.3)
#axes[1].set_ylim(0.2, 2.3)

# Increase tick label font size for both x and y axes

axes[1].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[1].legend(handles=[line2, line3, line4],loc="upper left", fontsize = 16)


# Adjust layout to prevent overlapping
plt.tight_layout()

# Save the plot to a file (e.g., PNG format)
#plt.savefig('\\Supplement\\Sim_PtoZ_SDhigh.png', dpi=300)

# Show the plot
#plt.show()
#display(fig)

# %%
# Set Matplotlib to use LaTeX
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'

# Plotting

# Increase plot size
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))  # 1 row, 2 columns


# Plotting
line1 = axes[0].plot(df_fromZ_low['MeanZ'], df_fromZ_low['MeanZ'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[0].scatter(df_fromZ_low['MeanZ'], df_fromZ_low['EstMeanZ_b_samp'], color='deepskyblue', marker='o', s=15, label="Sampling")
line4 = axes[0].scatter(df_fromZ_low['MeanZ'], df_fromZ_low['EstMeanZ_b_opt_samp'], color='red', marker='o', s=15, label="Optimization")
line5 = axes[0].scatter(df_fromZ_low['MeanZ'], df_fromZ_low['NaiveB'], color='darkviolet', marker='o', s=15, label="Naive")

# Set labels and limits
axes[0].set_xlabel("Simulated mean zBMI", fontsize = 18)
axes[0].set_ylabel("Estimated mean zBMI", fontsize = 18)
#axes[0].set_xlim(-0.25, 1.75)
#axes[0].set_ylim(-0.5, 2.5)

# Increase tick label font size for both x and y axes
axes[0].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[0].legend(handles=[line3, line4, line5],loc="upper left", fontsize = 16)

## PLOT 2
                      
# Plotting
line1 = axes[1].plot(df_fromZ_low['SDZ'], df_fromZ_low['SDZ'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[1].scatter(df_fromZ_low['SDZ'], df_fromZ_low['EstSDZ_b_samp'], color='deepskyblue', marker='o', s=15, label="Sampling")
line4 = axes[1].scatter(df_fromZ_low['SDZ'], df_fromZ_low['EstSDZ_b_opt_samp'], color='red', marker='o', s=15, label="Optimization")
    
# Set labels and limits
axes[1].set_xlabel("Simulated SD zBMI", fontsize = 18)
axes[1].set_ylabel("Estimated SD zBMI", fontsize = 18)
#axes[1].set_xlim(0.2, 2.3)
#axes[1].set_ylim(0.2, 2.3)

# Increase tick label font size for both x and y axes

axes[1].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[1].legend(handles=[line3, line4],loc="best", fontsize = 16)


# Adjust layout to prevent overlapping
plt.tight_layout()

# Save the plot to a file (e.g., PNG format)
#plt.savefig('\\Supplement\\Sim_BtoZ_S1_SDlow.png', dpi=300)

# Show the plot
#plt.show()
#display(fig)

# %%
# Set Matplotlib to use LaTeX
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'

# Plotting

# Increase plot size
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))  # 1 row, 2 columns


# Plotting
line1 = axes[0].plot(df_fromZ_mid['MeanZ'], df_fromZ_mid['MeanZ'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[0].scatter(df_fromZ_mid['MeanZ'], df_fromZ_mid['EstMeanZ_b_samp'], color='deepskyblue', marker='o', s=15, label="Sampling")
line4 = axes[0].scatter(df_fromZ_mid['MeanZ'], df_fromZ_mid['EstMeanZ_b_opt_samp'], color='red', marker='o', s=15, label="Optimization")
line5 = axes[0].scatter(df_fromZ_mid['MeanZ'], df_fromZ_mid['NaiveB'], color='darkviolet', marker='o', s=15, label="Naive")

# Set labels and limits
axes[0].set_xlabel("Simulated mean zBMI", fontsize = 18)
axes[0].set_ylabel("Estimated mean zBMI", fontsize = 18)
#axes[0].set_xlim(-0.25, 1.75)
axes[0].set_ylim(-2.5, 2.5)

# Increase tick label font size for both x and y axes
axes[0].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[0].legend(handles=[line3, line4, line5],loc="upper left", fontsize = 16)

## PLOT 2
                      
# Plotting
line1 = axes[1].plot(df_fromZ_mid['SDZ'], df_fromZ_mid['SDZ'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[1].scatter(df_fromZ_mid['SDZ'], df_fromZ_mid['EstSDZ_b_samp'], color='deepskyblue', marker='o', s=15, label="Sampling")
line4 = axes[1].scatter(df_fromZ_mid['SDZ'], df_fromZ_mid['EstSDZ_b_opt_samp'], color='red', marker='o', s=15, label="Optimization")
    
# Set labels and limits
axes[1].set_xlabel("Simulated SD zBMI", fontsize = 18)
axes[1].set_ylabel("Estimated SD zBMI", fontsize = 18)
#axes[1].set_xlim(0.2, 2.3)
axes[1].set_ylim(0, 5)

# Increase tick label font size for both x and y axes

axes[1].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[1].legend(handles=[line3, line4],loc="best", fontsize = 16)


# Adjust layout to prevent overlapping
plt.tight_layout()

# Save the plot to a file (e.g., PNG format)
#plt.savefig('\\Main\\Sim_BtoZ_S1_SDmid.png', dpi=300)

# Show the plot
#plt.show()
#display(fig)

# %%
# Find the index of the row with the minimum value of EstMeanZ_b_samp
min_index = df_fromZ_mid['EstMeanZ_b_samp'].idxmin()

# Get the corresponding row
min_row = df_fromZ_mid.loc[min_index]

# Print the values of MeanZ, EstMeanZ_b_samp, and EstSDZ_b_samp
print(f"MeanZ: {min_row['MeanZ']}")
print(f"EstMeanZ_b_samp: {min_row['EstMeanZ_b_samp']}")
print(f"EstSDZ_b_samp: {min_row['EstSDZ_b_samp']}")
# Out:
# MeanZ: 1.59195603099315
# EstMeanZ_b_samp: -9.178425205203071
# EstSDZ_b_samp: 34.0488952999442

# %%
# Set Matplotlib to use LaTeX
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'

# Plotting

# Increase plot size
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))  # 1 row, 2 columns


# Plotting
line1 = axes[0].plot(df_fromZ_high['MeanZ'], df_fromZ_high['MeanZ'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[0].scatter(df_fromZ_high['MeanZ'], df_fromZ_high['EstMeanZ_b_samp'], color='deepskyblue', marker='o', s=15, label="Sampling")
line4 = axes[0].scatter(df_fromZ_high['MeanZ'], df_fromZ_high['EstMeanZ_b_opt_samp'], color='red', marker='o', s=15, label="Optimization")
line5 = axes[0].scatter(df_fromZ_high['MeanZ'], df_fromZ_high['NaiveB'], color='darkviolet', marker='o', s=15, label="Naive")

# Set labels and limits
axes[0].set_xlabel("Simulated mean zBMI", fontsize = 18)
axes[0].set_ylabel("Estimated mean zBMI", fontsize = 18)
#axes[0].set_xlim(-0.25, 1.75)
axes[0].set_ylim(-4, 4)

# Increase tick label font size for both x and y axes
axes[0].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[0].legend(handles=[line3, line4, line5],loc="upper left", fontsize = 16)

## PLOT 2
                      
# Plotting
line1 = axes[1].plot(df_fromZ_high['SDZ'], df_fromZ_high['SDZ'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[1].scatter(df_fromZ_high['SDZ'], df_fromZ_high['EstSDZ_b_samp'], color='deepskyblue', marker='o', s=15, label="Sampling")
line4 = axes[1].scatter(df_fromZ_high['SDZ'], df_fromZ_high['EstSDZ_b_opt_samp'], color='red', marker='o', s=15, label="Optimization")
    
# Set labels and limits
axes[1].set_xlabel("Simulated SD zBMI", fontsize = 18)
axes[1].set_ylabel("Estimated SD zBMI", fontsize = 18)
#axes[1].set_xlim(0.2, 2.3)
axes[1].set_ylim(0, 5)

# Increase tick label font size for both x and y axes

axes[1].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[1].legend(handles=[line3, line4],loc="best", fontsize = 16)


# Adjust layout to prevent overlapping
plt.tight_layout()

# Save the plot to a file (e.g., PNG format)
#plt.savefig('\\Supplement\\Sim_BtoZ_S1_SDhigh.png', dpi=300)

# Show the plot
#plt.show()
#display(fig)

# %%
# Count the number of values in df_fromZ_high['EstMeanZ_b_samp'] that are less than -4
count_mean = (df_fromZ_high['EstMeanZ_b_samp'] < -4).sum()
count_SD = (df_fromZ_high['EstSDZ_b_samp'] > 5).sum()

# Print the result
print(f"Number of means less than -4: {count_mean}")
print(f"Number of SDs >5: {count_SD}")
# Out:
# Number of means less than -4: 29
# Number of SDs >5: 32

# %%
# Set Matplotlib to use LaTeX
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'

# Plotting

# Increase plot size
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))  # 1 row, 2 columns


# Plotting
line1 = axes[0].plot(df_fromB_low['MeanZ'], df_fromB_low['MeanZ'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[0].scatter(df_fromB_low['MeanZ'], df_fromB_low['EstMeanZ_b_samp'], color='deepskyblue', marker='o', s=15, label="Sampling")
#converged only
df_converged = df_fromB_low[df_fromB_low['ConvergeB'] == 'Y']
line4 = axes[0].scatter(df_converged['MeanZ'], df_converged['EstMeanZ_b_opt_samp'], color='red', marker='o', s=15, label="Optimization")
line5 = axes[0].scatter(df_fromB_low['MeanZ'], df_fromB_low['NaiveB'], color='darkviolet', marker='o', s=15, label="Naive")

# Set labels and limits
axes[0].set_xlabel("Simulated mean zBMI", fontsize = 18)
axes[0].set_ylabel("Estimated mean zBMI", fontsize = 18)
#axes[0].set_xlim(-0.25, 1.75)
#axes[0].set_ylim(-0.5, 2.5)

# Increase tick label font size for both x and y axes
axes[0].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[0].legend(handles=[line3, line4, line5],loc="upper left", fontsize = 16)

## PLOT 2
                      
# Plotting
line1 = axes[1].plot(df_fromB_low['SDZ'], df_fromB_low['SDZ'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[1].scatter(df_fromB_low['SDZ'], df_fromB_low['EstSDZ_b_samp'], color='deepskyblue', marker='o', s=15, label="Sampling")
line4 = axes[1].scatter(df_converged['SDZ'], df_converged['EstSDZ_b_opt_samp'], color='red', marker='o', s=15, label="Optimization")
    
# Set labels and limits
axes[1].set_xlabel("Simulated SD zBMI", fontsize = 18)
axes[1].set_ylabel("Estimated SD zBMI", fontsize = 18)
#axes[1].set_xlim(0.2, 2.3)
#axes[1].set_ylim(0.2, 2.3)

# Increase tick label font size for both x and y axes

axes[1].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[1].legend(handles=[line3, line4],loc="best", fontsize = 16)


# Adjust layout to prevent overlapping
plt.tight_layout()

# Save the plot to a file (e.g., PNG format)
#plt.savefig('\\Supplement\\Sim_BtoZ_S2_SDlow.png', dpi=300)

# Show the plot
#plt.show()
#display(fig)

# %%
# Set Matplotlib to use LaTeX
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'

# Plotting

# Increase plot size
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))  # 1 row, 2 columns


# Plotting
line1 = axes[0].plot(df_fromB_mid['MeanZ'], df_fromB_mid['MeanZ'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[0].scatter(df_fromB_mid['MeanZ'], df_fromB_mid['EstMeanZ_b_samp'], color='deepskyblue', marker='o', s=15, label="Sampling")
#converged only
df_converged = df_fromB_mid[df_fromB_mid['ConvergeB'] == 'Y']
line4 = axes[0].scatter(df_converged['MeanZ'], df_converged['EstMeanZ_b_opt_samp'], color='red', marker='o', s=15, label="Optimization")
line5 = axes[0].scatter(df_fromB_mid['MeanZ'], df_fromB_mid['NaiveB'], color='darkviolet', marker='o', s=15, label="Naive")

# Set labels and limits
axes[0].set_xlabel("Simulated mean zBMI", fontsize = 18)
axes[0].set_ylabel("Estimated mean zBMI", fontsize = 18)
#axes[0].set_xlim(-0.25, 1.75)
#axes[0].set_ylim(-0.5, 2.5)

# Increase tick label font size for both x and y axes
axes[0].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[0].legend(handles=[line3, line4, line5],loc="upper left", fontsize = 16)

## PLOT 2
                      
# Plotting
line1 = axes[1].plot(df_fromB_mid['SDZ'], df_fromB_mid['SDZ'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[1].scatter(df_fromB_mid['SDZ'], df_fromB_mid['EstSDZ_b_samp'], color='deepskyblue', marker='o', s=15, label="Sampling")
line4 = axes[1].scatter(df_converged['SDZ'], df_converged['EstSDZ_b_opt_samp'], color='red', marker='o', s=15, label="Optimization")
    
# Set labels and limits
axes[1].set_xlabel("Simulated SD zBMI", fontsize = 18)
axes[1].set_ylabel("Estimated SD zBMI", fontsize = 18)
#axes[1].set_xlim(0.2, 2.3)
#axes[1].set_ylim(0.2, 2.3)

# Increase tick label font size for both x and y axes

axes[1].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[1].legend(handles=[line3, line4],loc="best", fontsize = 16)


# Adjust layout to prevent overlapping
plt.tight_layout()

# Save the plot to a file (e.g., PNG format)
#plt.savefig('\\Main\\Sim_BtoZ_S2_SDmid.png', dpi=300)

# Show the plot
#plt.show()
#display(fig)

# %%
# Set Matplotlib to use LaTeX
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'

# Plotting

# Increase plot size
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))  # 1 row, 2 columns


# Plotting
line1 = axes[0].plot(df_fromB_high['MeanZ'], df_fromB_high['MeanZ'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[0].scatter(df_fromB_high['MeanZ'], df_fromB_high['EstMeanZ_b_samp'], color='deepskyblue', marker='o', s=15, label="Sampling")
#converged only
df_converged = df_fromB_high[df_fromB_high['ConvergeB'] == 'Y']
line4 = axes[0].scatter(df_converged['MeanZ'], df_converged['EstMeanZ_b_opt_samp'], color='red', marker='o', s=15, label="Optimization")
line5 = axes[0].scatter(df_fromB_high['MeanZ'], df_fromB_high['NaiveB'], color='darkviolet', marker='o', s=15, label="Naive")

# Set labels and limits
axes[0].set_xlabel("Simulated mean zBMI", fontsize = 18)
axes[0].set_ylabel("Estimated mean zBMI", fontsize = 18)
#axes[0].set_xlim(-0.25, 1.75)
#axes[0].set_ylim(-0.5, 2.5)

# Increase tick label font size for both x and y axes
axes[0].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[0].legend(handles=[line3, line4, line5],loc="upper left", fontsize = 16)

## PLOT 2
                      
# Plotting
line1 = axes[1].plot(df_fromB_high['SDZ'], df_fromB_high['SDZ'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[1].scatter(df_fromB_high['SDZ'], df_fromB_high['EstSDZ_b_samp'], color='deepskyblue', marker='o', s=15, label="Sampling")
line4 = axes[1].scatter(df_converged['SDZ'], df_converged['EstSDZ_b_opt_samp'], color='red', marker='o', s=15, label="Optimization")
    
# Set labels and limits
axes[1].set_xlabel("Simulated SD zBMI", fontsize = 18)
axes[1].set_ylabel("Estimated SD zBMI", fontsize = 18)
#axes[1].set_xlim(0.2, 2.3)
#axes[1].set_ylim(0.2, 2.3)

# Increase tick label font size for both x and y axes

axes[1].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[1].legend(handles=[line3, line4],loc="best", fontsize = 16)


# Adjust layout to prevent overlapping
plt.tight_layout()

# Save the plot to a file (e.g., PNG format)
#plt.savefig('\\Supplement\\Sim_BtoZ_S2_SDhigh.png', dpi=300)

# Show the plot
#plt.show()
#display(fig)

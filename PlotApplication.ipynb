# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
fp = "\\PlottingData\\"
df_zp = pd.read_csv(fp + "z_for_perc.csv")
df_psamp = pd.read_csv(fp + "perc_sampling.csv")
df_popt_dist = pd.read_csv(fp + "perc_opt_dist.csv")
df_popt_samp = pd.read_csv(fp + "perc_opt_samp.csv")
df_pcdf = pd.read_csv(fp + "perc_analytic.csv")

# %%
# Set Matplotlib to use LaTeX
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'

# Increase plot size
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))  # 1 row, 2 columns


# Plotting
line1 = axes[0].plot(df_zp['mean'], df_zp['mean'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[0].scatter(df_zp['mean'], df_popt_samp['mean'], color='red', marker='o', s=15, label="Optimization")
line4 = axes[0].scatter(df_zp['mean'], df_pcdf['mean'], color='green', marker='o', s=15, label="Analytical")
line5 = axes[0].scatter(df_zp['mean'], df_psamp['mean'], color='deepskyblue', marker='o', s=15, label="Sampling")

# Set labels and limits
axes[0].set_xlabel("Reported mean zBMI", fontsize = 18)
axes[0].set_ylabel("Estimated mean zBMI", fontsize = 18)
axes[0].set_xlim(-0.25, 1.75)
axes[0].set_ylim(-0.5, 2.5)

# Increase tick label font size for both x and y axes
axes[0].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[0].legend(handles=[line4, line5, line3],loc="upper left", fontsize = 16)

## PLOT 2
                      
# Plotting
line1 = axes[1].plot(df_zp['SD'], df_zp['SD'], c='black', marker='', linestyle='-', label="_nolegend_")
line3 = axes[1].scatter(df_zp['SD'], df_popt_samp['SD'], color='red', marker='o', s=15, label="Optimization")
line4 = axes[1].scatter(df_zp['SD'], df_pcdf['SD'], color='green', marker='o', s=15, label="Analytical")
line5 = axes[1].scatter(df_zp['SD'], df_psamp['SD'], color='deepskyblue', marker='o', s=15, label="Sampling")

# Set labels and limits
axes[1].set_xlabel("Reported SD zBMI", fontsize = 18)
axes[1].set_ylabel("Estimated SD zBMI", fontsize = 18)
axes[1].set_xlim(0.2, 2.3)
axes[1].set_ylim(0.2, 2.3)

# Increase tick label font size for both x and y axes

axes[1].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[1].legend(handles=[line4, line5, line3],loc="upper left", fontsize = 16)


# Adjust layout to prevent overlapping
plt.tight_layout()

# Save the plot to a file (e.g., PNG format)
#plt.savefig('\\Main\\Main-z-from-perc.png', dpi=300)

# Show the plot
#plt.show()
#display(fig)

# %%
df_zb = pd.read_csv(fp + "z_for_bmi.csv")
df_bsamp_norm = pd.read_csv(fp + "bmi_sampling_aNorm.csv")
df_bsamp_unif = pd.read_csv(fp + "bmi_sampling_aUnif.csv")
df_bopt_dist = pd.read_csv(fp + "bmi_opt_dist.csv")
df_bopt_samp = pd.read_csv(fp + "bmi_opt_samp.csv")
#print(len(df_zb))

# %%
# Set Matplotlib to use LaTeX
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'

# Increase plot size
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))  # 1 row, 2 columns


# Plotting
line1 = axes[0].plot(df_zb['mean'], df_zb['mean'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[0].scatter(df_zb['mean'], df_bopt_samp['mean'], color='red', marker='o', s=15, label="Optimization")
line4 = axes[0].scatter(df_zb['mean'], df_bsamp_norm['mean'], color='deepskyblue', marker='o', s=15, label="Sampling")

# Set labels and limits
axes[0].set_xlabel("Reported mean zBMI", fontsize = 18)
axes[0].set_ylabel("Estimated mean zBMI", fontsize = 18)
axes[0].set_xlim(-0.5, 3)
axes[0].set_ylim(-0.7, 3)

# Increase tick label font size for both x and y axes
axes[0].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[0].legend(handles=[line4, line3],loc="upper left", fontsize = 16)

## PLOT 2
                      
# Plotting
line1 = axes[1].plot(df_zb['SD'], df_zb['SD'], c='black', marker='', linestyle='-', label="_nolegend_")
line3 = axes[1].scatter(df_zb['SD'], df_bopt_samp['SD'], color='red', marker='o', s=15, label="Optimization")
line4 = axes[1].scatter(df_zb['SD'], df_bsamp_norm['SD'], color='deepskyblue', marker='o', s=15, label="Sampling")

# Set labels and limits
axes[1].set_xlabel("Reported SD zBMI", fontsize = 18)
axes[1].set_ylabel("Estimated SD zBMI", fontsize = 18)
axes[1].set_xlim(0, 2.3)
axes[1].set_ylim(0, 4)

# Increase tick label font size for both x and y axes

axes[1].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[1].legend(handles=[line4, line3],loc="upper left", fontsize = 16)


# Adjust layout to prevent overlapping
plt.tight_layout()

# Save the plot to a file (e.g., PNG format)
#plt.savefig('\\Main\\Main-z-from-bmi.png', dpi=300)

# Show the plot
#plt.show()
#display(fig)

# %%
## Appendix E: comparing age distributions

# Set Matplotlib to use LaTeX
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'


# Increase plot size
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))  # 1 row, 2 columns


# Plotting
line1 = axes[0].plot(df_zb['mean'], df_zb['mean'], color='black', marker='', linestyle='-', label='_nolegend_')
line2 = axes[0].scatter(df_zb['mean'], df_bsamp_unif['mean'], color='royalblue', marker='o', s=15, label="Sampling (age: uniform)")
line3 = axes[0].scatter(df_zb['mean'], df_bsamp_norm['mean'], color='deepskyblue', marker='o', s=15, label="Sampling (age: normal)")

# Set labels and limits
axes[0].set_xlabel("Reported mean zBMI", fontsize = 18)
axes[0].set_ylabel("Estimated mean zBMI", fontsize = 18)
axes[0].set_xlim(-0.5, 3)
axes[0].set_ylim(-0.7, 3)

# Increase tick label font size for both x and y axes
axes[0].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[0].legend(handles=[line3, line2],loc="upper left", fontsize = 16)

## PLOT 2
                      
# Plotting
line1 = axes[1].plot(df_zb['SD'], df_zb['SD'], c='black', marker='', linestyle='-', label="_nolegend_")
line2 = axes[1].scatter(df_zb['SD'], df_bsamp_unif['SD'], color='royalblue', marker='o', s=15, label="Sampling (age: uniform)")
line4 = axes[1].scatter(df_zb['SD'], df_bsamp_norm['SD'], color='deepskyblue', marker='o', s=15, label="Sampling (age: normal)")

# Set labels and limits
axes[1].set_xlabel("Reported SD zBMI", fontsize = 18)
axes[1].set_ylabel("Estimated SD zBMI", fontsize = 18)
axes[1].set_xlim(0, 2.3)
axes[1].set_ylim(0, 4)

# Increase tick label font size for both x and y axes

axes[1].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[1].legend(handles=[line3, line2],loc="upper left", fontsize = 16)


# Adjust layout to prevent overlapping
plt.tight_layout()

# Save the plot to a file (e.g., PNG format)
#plt.savefig('\\Supplement\\App-age-dist.png', dpi=300)

# Show the plot
#plt.show()
#display(fig)

# %%
## Appendix F: exploring outliers

# Data set without studies that don't report a reference chart
df_zb1 = df_zb[df_zb['chart_ref'] == "Y"]
df_bsamp_norm1 = df_bsamp_norm[df_bsamp_norm['chart_ref'] == "Y"]
df_bopt_dist1 = df_bopt_dist[df_bopt_dist['chart_ref'] == "Y"]
df_bopt_samp1 = df_bopt_samp[df_bopt_samp['chart_ref'] == "Y"]

# Remove unadjust for cluster
df_zb2 = df_zb1[df_zb1['UnAdj_cluster'] == "N"]
df_bsamp_norm2 = df_bsamp_norm1[df_bsamp_norm1['UnAdj_cluster'] == "N"]
df_bopt_dist2 = df_bopt_dist1[df_bopt_dist1['UnAdj_cluster'] == "N"]
df_bopt_samp2 = df_bopt_samp1[df_bopt_samp1['UnAdj_cluster'] == "N"]

# Remove FU from CS
df_zb3 = df_zb2[~((df_bsamp_norm2['test_type'] == "Baseline and CS") & (df_bsamp_norm2['time'] != "baseline"))]
df_bsamp_norm3 = df_bsamp_norm2[~((df_bsamp_norm2['test_type'] == "Baseline and CS") & (df_bsamp_norm2['time'] != "baseline"))]
df_bopt_dist3 = df_bopt_dist2[~((df_bopt_dist2['test_type'] == "Baseline and CS") & (df_bopt_dist2['time'] != "baseline"))]
df_bopt_samp3 = df_bopt_samp2[~((df_bopt_samp2['test_type'] == "Baseline and CS") & (df_bopt_samp2['time'] != "baseline"))]

# %%
# Set Matplotlib to use LaTeX
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'

# Increase plot size
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 12))  # 2 rows, 2 columns

## PLOT 1
# Plotting
line1 = axes[0,0].plot(df_zb['mean'], df_zb['mean'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[0,0].scatter(df_zb['mean'], df_bopt_samp['mean'], color='red', marker='o', s=15, label="Optimization")
line4 = axes[0,0].scatter(df_zb['mean'], df_bsamp_norm['mean'], color='deepskyblue', s=15, marker='o', label="Sampling")

# Set labels and limits
axes[0,0].set_xlabel("Reported mean zBMI", fontsize = 18)
axes[0,0].set_ylabel("Estimated mean zBMI", fontsize = 18)
axes[0,0].set_title("Original", fontsize = 20)
axes[0,0].set_xlim(-0.5, 3)
axes[0,0].set_ylim(-0.7, 3)

# Increase tick label font size for both x and y axes
axes[0,0].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[0,0].legend(handles=[line4, line3],loc="upper left", fontsize = 16)


## PLOT 2
# Plotting
line1 = axes[0,1].plot(df_zb1['mean'], df_zb1['mean'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[0,1].scatter(df_zb1['mean'], df_bopt_samp1['mean'], color='red', marker='o', s=15, label="Optimization")
line4 = axes[0,1].scatter(df_zb1['mean'], df_bsamp_norm1['mean'], color='deepskyblue', marker='o', s=15, label="Sampling")

# Set labels and limits
axes[0,1].set_xlabel("Reported mean zBMI", fontsize = 18)
axes[0,1].set_ylabel("Estimated mean zBMI", fontsize = 18)
axes[0,1].set_title("Without (i)", fontsize = 20)
axes[0,1].set_xlim(-0.5, 3)
axes[0,1].set_ylim(-0.7, 3)

# Increase tick label font size for both x and y axes
axes[0,1].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[0,1].legend(handles=[line4, line3],loc="upper left", fontsize = 16)

## PLOT 3
                      
# Plotting
line1 = axes[1,0].plot(df_zb2['mean'], df_zb2['mean'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[1,0].scatter(df_zb2['mean'], df_bopt_samp2['mean'], color='red', marker='o',  s=15, label="Optimization")
line4 = axes[1,0].scatter(df_zb2['mean'], df_bsamp_norm2['mean'], color='deepskyblue', marker='o', s=15, label="Sampling")

# Set labels and limits
axes[1,0].set_xlabel("Reported mean zBMI", fontsize = 18)
axes[1,0].set_ylabel("Estimated mean zBMI", fontsize = 18)
axes[1,0].set_title("Without (i) + (ii)", fontsize = 20)
axes[1,0].set_xlim(-0.5, 3)
axes[1,0].set_ylim(-0.7, 3)

# Increase tick label font size for both x and y axes
axes[1,0].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[1,0].legend(handles=[line4, line3],loc="upper left", fontsize = 16)


## PLOT 4
# Plotting
line1 = axes[1,1].plot(df_zb3['mean'], df_zb3['mean'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[1,1].scatter(df_zb3['mean'], df_bopt_samp3['mean'], color='red', marker='o', s=15, label="Optimization")
line4 = axes[1,1].scatter(df_zb3['mean'], df_bsamp_norm3['mean'], color='deepskyblue', marker='o', s=15, label="Sampling")

# Set labels and limits
axes[1,1].set_xlabel("Reported mean zBMI", fontsize = 18)
axes[1,1].set_ylabel("Estimated mean zBMI", fontsize = 18)
axes[1,1].set_title("Without (i) + (ii) + (iii)", fontsize = 20)
axes[1,1].set_xlim(-0.5, 3)
axes[1,1].set_ylim(-0.7, 3)

# Increase tick label font size for both x and y axes
axes[1,1].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[1,1].legend(handles=[line4, line3],loc="upper left", fontsize = 16)


# Adjust layout to prevent overlapping
plt.tight_layout()

# Save the plot to a file (e.g., PNG format)
#plt.savefig('\\Supplement\\App-z-b-outliers-mean.png', dpi=300)

# Show the plot
#plt.show()
#display(fig)

# %%
# Set Matplotlib to use LaTeX
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'

# Increase plot size
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 12))  # 2 rows, 2 columns

## PLOT 1
# Plotting
line1 = axes[0,0].plot(df_zb['SD'], df_zb['SD'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[0,0].scatter(df_zb['SD'], df_bopt_samp['SD'], color='red', marker='o', s=15, label="Optimization")
line4 = axes[0,0].scatter(df_zb['SD'], df_bsamp_norm['SD'], color='deepskyblue', marker='o', s=15, label="Sampling")

# Set labels and limits
axes[0,0].set_xlabel("Reported SD zBMI", fontsize = 18)
axes[0,0].set_ylabel("Estimated SD zBMI", fontsize = 18)
axes[0,0].set_title("Original", fontsize = 20)
axes[0,0].set_xlim(0, 2.3)
axes[0,0].set_ylim(0, 4)

# Increase tick label font size for both x and y axes
axes[0,0].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[0,0].legend(handles=[line4, line3],loc="upper left", fontsize = 16)


## PLOT 2
# Plotting
line1 = axes[0,1].plot(df_zb1['SD'], df_zb1['SD'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[0,1].scatter(df_zb1['SD'], df_bopt_samp1['SD'], color='red', marker='o', s=15, label="Optimization")
line4 = axes[0,1].scatter(df_zb1['SD'], df_bsamp_norm1['SD'], color='deepskyblue', marker='o', s=15, label="Sampling")

# Set labels and limits
axes[0,1].set_xlabel("Reported SD zBMI", fontsize = 18)
axes[0,1].set_ylabel("Estimated SD zBMI", fontsize = 18)
axes[0,1].set_title("Without (i)", fontsize = 20)
axes[0,1].set_xlim(0, 2.3)
axes[0,1].set_ylim(0, 4)

# Increase tick label font size for both x and y axes
axes[0,1].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[0,1].legend(handles=[line4, line3],loc="upper left", fontsize = 16)

## PLOT 3
                      
# Plotting
line1 = axes[1,0].plot(df_zb2['SD'], df_zb2['SD'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[1,0].scatter(df_zb2['SD'], df_bopt_samp2['SD'], color='red', marker='o', s=15, label="Optimization")
line4 = axes[1,0].scatter(df_zb2['SD'], df_bsamp_norm2['SD'], color='deepskyblue', marker='o', s=15, label="Sampling")

# Set labels and limits
axes[1,0].set_xlabel("Reported SD zBMI", fontsize = 18)
axes[1,0].set_ylabel("Estimated SD zBMI", fontsize = 18)
axes[1,0].set_title("Without (i) + (ii)", fontsize = 20)
axes[1,0].set_xlim(0, 2.3)
axes[1,0].set_ylim(0, 4)

# Increase tick label font size for both x and y axes
axes[1,0].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[1,0].legend(handles=[line4, line3],loc="upper left", fontsize = 16)


## PLOT 4
# Plotting
line1 = axes[1,1].plot(df_zb3['SD'], df_zb3['SD'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[1,1].scatter(df_zb3['SD'], df_bopt_samp3['SD'], color='red', marker='o', s=15, label="Optimization")
line4 = axes[1,1].scatter(df_zb3['SD'], df_bsamp_norm3['SD'], color='deepskyblue', marker='o', s=15, label="Sampling")

# Set labels and limits
axes[1,1].set_xlabel("Reported SD zBMI", fontsize = 18)
axes[1,1].set_ylabel("Estimated SD zBMI", fontsize = 18)
axes[1,1].set_title("Without (i) + (ii) + (iii)", fontsize = 20)
axes[1,1].set_xlim(0, 2.3)
axes[1,1].set_ylim(0, 4)

# Increase tick label font size for both x and y axes
axes[1,1].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[1,1].legend(handles=[line4, line3],loc="upper left", fontsize = 16)


# Adjust layout to prevent overlapping
plt.tight_layout()

# Save the plot to a file (e.g., PNG format)
#plt.savefig('\\Supplement\\App-z-b-outliers-SD.png', dpi=300)

# Show the plot
#plt.show()
#display(fig)

# %%
## CHECK REFERENCE CHARTS

# Data set without studies that don't report a reference chart
df_zb1 = df_zb[df_zb['chart_ref'] == "Y"]
df_bsamp_norm1 = df_bsamp_norm[df_bsamp_norm['chart_ref'] == "Y"]
df_bopt_dist1 = df_bopt_dist[df_bopt_dist['chart_ref'] == "Y"]
df_bopt_samp1 = df_bopt_samp[df_bopt_samp['chart_ref'] == "Y"]
print(len(df_zb1))

#CDC:
df_zb1_CDC = df_zb1[df_zb1['chart'] == "CDC"]
df_bsamp_norm1_CDC = df_bsamp_norm1[df_bsamp_norm1['chart'] == "CDC"]
df_bopt_dist1_CDC = df_bopt_dist1[df_bopt_dist1['chart'] == "CDC"]
df_bopt_samp1_CDC = df_bopt_samp1[df_bopt_samp1['chart'] == "CDC"]
print(len(df_zb1_CDC))

#WHO:
df_zb1_WHO = df_zb1[df_zb1['chart'] == "WHO"]
df_bsamp_norm1_WHO = df_bsamp_norm1[df_bsamp_norm1['chart'] == "WHO"]
df_bopt_dist1_WHO = df_bopt_dist1[df_bopt_dist1['chart'] == "WHO"]
df_bopt_samp1_WHO = df_bopt_samp1[df_bopt_samp1['chart'] == "WHO"]
print(len(df_zb1_WHO))

#IOTF:
df_zb1_IOTF = df_zb1[df_zb1['chart'] == "IOTF"]
df_bsamp_norm1_IOTF = df_bsamp_norm1[df_bsamp_norm1['chart'] == "IOTF"]
df_bopt_dist1_IOTF = df_bopt_dist1[df_bopt_dist1['chart'] == "IOTF"]
df_bopt_samp1_IOTF = df_bopt_samp1[df_bopt_samp1['chart'] == "IOTF"]
print(len(df_zb1_IOTF))
# Out:
# 155
# 48
# 52
# 46

# %%
# Set Matplotlib to use LaTeX
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'

# Increase plot size
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 12))  # 2 rows, 2 columns

## PLOT 1
# Plotting
line1 = axes[0,0].plot(df_zb1['mean'], df_zb1['mean'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[0,0].scatter(df_zb1['mean'], df_bopt_samp1['mean'], color='red', marker='o', s=15, label="Optimization")
line4 = axes[0,0].scatter(df_zb1['mean'], df_bsamp_norm1['mean'], color='deepskyblue', marker='o', s=15, label="Sampling")

# Set labels and limits
axes[0,0].set_xlabel("Reported mean zBMI", fontsize = 18)
axes[0,0].set_ylabel("Estimated mean zBMI", fontsize = 18)
axes[0,0].set_title("All charts (reported)", fontsize = 20)
axes[0,0].set_xlim(-0.5, 3)
axes[0,0].set_ylim(-0.7, 3)

# Increase tick label font size for both x and y axes
axes[0,0].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[0,0].legend(handles=[line4, line3],loc="upper left", fontsize = 16)


## PLOT 2
# Plotting
line1 = axes[0,1].plot(df_zb1['mean'], df_zb1['mean'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[0,1].scatter(df_zb1_CDC['mean'], df_bopt_samp1_CDC['mean'], color='red', marker='o', s=15, label="Optimization")
line4 = axes[0,1].scatter(df_zb1_CDC['mean'], df_bsamp_norm1_CDC['mean'], color='deepskyblue', marker='o', s=15, label="Sampling")

# Set labels and limits
axes[0,1].set_xlabel("Reported mean zBMI", fontsize = 18)
axes[0,1].set_ylabel("Estimated mean zBMI", fontsize = 18)
axes[0,1].set_title("CDC", fontsize = 20)
axes[0,1].set_xlim(-0.5, 3)
axes[0,1].set_ylim(-0.7, 3)

# Increase tick label font size for both x and y axes
axes[0,1].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[0,1].legend(handles=[line4, line3],loc="upper left", fontsize = 16)

## PLOT 3
                      
# Plotting
line1 = axes[1,0].plot(df_zb1['mean'], df_zb1['mean'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[1,0].scatter(df_zb1_WHO['mean'], df_bopt_samp1_WHO['mean'], color='red', marker='o', s=15, label="Optimization")
line4 = axes[1,0].scatter(df_zb1_WHO['mean'], df_bsamp_norm1_WHO['mean'], color='deepskyblue', marker='o', s=15, label="Sampling")

# Set labels and limits
axes[1,0].set_xlabel("Reported mean zBMI", fontsize = 18)
axes[1,0].set_ylabel("Estimated mean zBMI", fontsize = 18)
axes[1,0].set_title("WHO", fontsize = 20)
axes[1,0].set_xlim(-0.5, 3)
axes[1,0].set_ylim(-0.7, 3)

# Increase tick label font size for both x and y axes
axes[1,0].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[1,0].legend(handles=[line4, line3],loc="upper left", fontsize = 16)


## PLOT 4
# Plotting
line1 = axes[1,1].plot(df_zb1['mean'], df_zb1['mean'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[1,1].scatter(df_zb1_IOTF['mean'], df_bopt_samp1_IOTF['mean'], color='red', marker='o', s=15, label="Optimization")
line4 = axes[1,1].scatter(df_zb1_IOTF['mean'], df_bsamp_norm1_IOTF['mean'], color='deepskyblue', marker='o', s=15, label="Sampling")

# Set labels and limits
axes[1,1].set_xlabel("Reported mean zBMI", fontsize = 18)
axes[1,1].set_ylabel("Estimated mean zBMI", fontsize = 18)
axes[1,1].set_title("IOTF", fontsize = 20)
axes[1,1].set_xlim(-0.5, 3)
axes[1,1].set_ylim(-0.7, 3)

# Increase tick label font size for both x and y axes
axes[1,1].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[1,1].legend(handles=[line4, line3],loc="upper left", fontsize = 16)


# Adjust layout to prevent overlapping
plt.tight_layout()

# Save the plot to a file (e.g., PNG format)
#plt.savefig('\\Supplement\\App-check-charts-mean.png', dpi=300)

# Show the plot
#plt.show()
#display(fig)

# %%
# Set Matplotlib to use LaTeX
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'

# Increase plot size
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 12))  # 2 rows, 2 columns

## PLOT 1
# Plotting
line1 = axes[0,0].plot(df_zb1['SD'], df_zb1['SD'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[0,0].scatter(df_zb1['SD'], df_bopt_samp1['SD'], color='red', marker='o', s=15, label="Optimization")
line4 = axes[0,0].scatter(df_zb1['SD'], df_bsamp_norm1['SD'], color='deepskyblue', marker='o', s=15, label="Sampling")

# Set labels and limits
axes[0,0].set_xlabel("Reported SD zBMI", fontsize = 18)
axes[0,0].set_ylabel("Estimated SD zBMI", fontsize = 18)
axes[0,0].set_title("All charts (reported)", fontsize = 20)
axes[0,0].set_xlim(0, 2.3)
axes[0,0].set_ylim(0, 4)

# Increase tick label font size for both x and y axes
axes[0,0].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[0,0].legend(handles=[line4, line3],loc="upper left", fontsize = 16)


## PLOT 2
# Plotting
line1 = axes[0,1].plot(df_zb1['SD'], df_zb1['SD'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[0,1].scatter(df_zb1_CDC['SD'], df_bopt_samp1_CDC['SD'], color='red', marker='o', s=15, label="Optimization")
line4 = axes[0,1].scatter(df_zb1_CDC['SD'], df_bsamp_norm1_CDC['SD'], color='deepskyblue', s=15, marker='o', label="Sampling")

# Set labels and limits
axes[0,1].set_xlabel("Reported SD zBMI", fontsize = 18)
axes[0,1].set_ylabel("Estimated SD zBMI", fontsize = 18)
axes[0,1].set_title("CDC", fontsize = 20)
axes[0,1].set_xlim(0, 2.3)
axes[0,1].set_ylim(0, 4)

# Increase tick label font size for both x and y axes
axes[0,1].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[0,1].legend(handles=[line4, line3],loc="upper left", fontsize = 16)

## PLOT 3
                      
# Plotting
line1 = axes[1,0].plot(df_zb1['SD'], df_zb1['SD'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[1,0].scatter(df_zb1_WHO['SD'], df_bopt_samp1_WHO['SD'], color='red', marker='o', s=15, label="Optimization")
line4 = axes[1,0].scatter(df_zb1_WHO['SD'], df_bsamp_norm1_WHO['SD'], color='deepskyblue', s=15, marker='o', label="Sampling")

# Set labels and limits
axes[1,0].set_xlabel("Reported SD zBMI", fontsize = 18)
axes[1,0].set_ylabel("Estimated SD zBMI", fontsize = 18)
axes[1,0].set_title("WHO", fontsize = 20)
axes[1,0].set_xlim(0, 2.3)
axes[1,0].set_ylim(0, 4)

# Increase tick label font size for both x and y axes
axes[1,0].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[1,0].legend(handles=[line4, line3],loc="upper left", fontsize = 16)


## PLOT 4
# Plotting
line1 = axes[1,1].plot(df_zb1['SD'], df_zb1['SD'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[1,1].scatter(df_zb1_IOTF['SD'], df_bopt_samp1_IOTF['SD'], color='red', marker='o', s=15, label="Optimization")
line4 = axes[1,1].scatter(df_zb1_IOTF['SD'], df_bsamp_norm1_IOTF['SD'], color='deepskyblue', marker='o', s=15, label="Sampling")

# Set labels and limits
axes[1,1].set_xlabel("Reported SD zBMI", fontsize = 18)
axes[1,1].set_ylabel("Estimated SD zBMI", fontsize = 18)
axes[1,1].set_title("IOTF", fontsize = 20)
axes[1,1].set_xlim(0, 2.3)
axes[1,1].set_ylim(0, 4)

# Increase tick label font size for both x and y axes
axes[1,1].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[1,1].legend(handles=[line4, line3],loc="upper left", fontsize = 16)


# Adjust layout to prevent overlapping
plt.tight_layout()

# Save the plot to a file (e.g., PNG format)
#plt.savefig('\\Supplement\\App-check-charts-SD.png', dpi=300)

# Show the plot
#plt.show()
#display(fig)

# %%
### Check convergence
df_zb0 = df_zb[df_bopt_dist['converge'] == "Y"]

df_bopt_dist0 = df_bopt_dist[df_bopt_dist['converge'] == "Y"]
df_bopt_samp0 = df_bopt_samp[df_bopt_samp['converge'] == "Y"]

print(len(df_zb0))
print(len(df_bopt_dist0))
print(len(df_bopt_samp0))
# Out:
# 184
# 184
# 184

# %%
# Set Matplotlib to use LaTeX
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'

# Increase plot size
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))  # 1 row, 2 columns


# Plotting
line1 = axes[0].plot(df_zb['mean'], df_zb['mean'], color='black', marker='', linestyle='-', label='_nolegend_')
line3 = axes[0].scatter(df_zb0['mean'], df_bopt_samp0['mean'], color='red', marker='o', s=15, label="Optimization")
#line4 = axes[0].scatter(df_zb['mean'], df_bsamp_norm['mean'], color='deepskyblue', marker='o', label="Sampling method")

# Set labels and limits
axes[0].set_xlabel("Reported mean zBMI", fontsize = 18)
axes[0].set_ylabel("Estimated mean zBMI", fontsize = 18)
axes[0].set_xlim(-0.5, 3)
axes[0].set_ylim(-0.7, 3)

# Increase tick label font size for both x and y axes
axes[0].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[0].legend(handles=[line3],loc="upper left", fontsize = 16)

## PLOT 2
                      
# Plotting
line1 = axes[1].plot(df_zb['SD'], df_zb['SD'], c='black', marker='', linestyle='-', label="_nolegend_")
line3 = axes[1].scatter(df_zb0['SD'], df_bopt_samp0['SD'], color='red', marker='o', s=15, label="Optimization")
#line4 = axes[1].scatter(df_zb['SD'], df_bsamp_norm['SD'], color='deepskyblue', marker='o', label="Sampling method")

# Set labels and limits
axes[1].set_xlabel("Reported SD zBMI", fontsize = 18)
axes[1].set_ylabel("Estimated SD zBMI", fontsize = 18)
axes[1].set_xlim(0, 2.3)
axes[1].set_ylim(0, 4)

# Increase tick label font size for both x and y axes

axes[1].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[1].legend(handles=[line3],loc="upper left", fontsize = 16)


# Adjust layout to prevent overlapping
plt.tight_layout()

# Save the plot to a file (e.g., PNG format)
#plt.savefig('\\Supplement\\App-converge-z-from-bmi.png', dpi=300)

# Show the plot
#plt.show()
#display(fig)

# %%
# Set Matplotlib to use LaTeX
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'

# Increase plot size
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))  # 1 row, 2 columns


# Plotting
line1 = axes[0].plot(df_zb['mean'], df_zb['mean'], color='black', marker='', linestyle='-', label='_nolegend_')
line2 = axes[0].scatter(df_zb['mean'], df_bopt_dist['mean'], color='orange', marker='o', s=15, label="Optimization (distribution)")
line3 = axes[0].scatter(df_zb['mean'], df_bopt_samp['mean'], color='red', marker='o', s=15, label="Optimization (sample)")

# Set labels and limits
axes[0].set_xlabel("Reported mean zBMI", fontsize = 18)
axes[0].set_ylabel("Estimated mean zBMI", fontsize = 18)
axes[0].set_xlim(-0.5, 3)
axes[0].set_ylim(-0.7, 3)

# Increase tick label font size for both x and y axes
axes[0].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[0].legend(handles=[line3, line2],loc="upper left", fontsize = 16)

## PLOT 2
                      
# Plotting
line1 = axes[1].plot(df_zb['SD'], df_zb['SD'], c='black', marker='', linestyle='-', label="_nolegend_")
line2 = axes[1].scatter(df_zb['SD'], df_bopt_dist['SD'], color='orange', marker='o', s=15, label="Optimization (distribution)")
line3 = axes[1].scatter(df_zb['SD'], df_bopt_samp['SD'], color='red', marker='o', s=15, label="Optimization (sample)")

# Set labels and limits
axes[1].set_xlabel("Reported SD zBMI", fontsize = 18)
axes[1].set_ylabel("Estimated SD zBMI", fontsize = 18)
axes[1].set_xlim(0, 2.3)
axes[1].set_ylim(0, 4)

# Increase tick label font size for both x and y axes

axes[1].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[1].legend(handles=[line3, line2],loc="upper left", fontsize = 16)


# Adjust layout to prevent overlapping
plt.tight_layout()

# Save the plot to a file (e.g., PNG format)
#plt.savefig('\\Supplement\\App-compare-opt.png', dpi=300)

# Show the plot
#plt.show()
#display(fig)

# %%
# Set Matplotlib to use LaTeX
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'

# Increase plot size
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))  # 1 row, 2 columns


# Plotting
line1 = axes[0].plot(df_zp['mean'], df_zp['mean'], color='black', marker='', linestyle='-', label='_nolegend_')
line2 = axes[0].scatter(df_zp['mean'], df_popt_dist['mean'], color='orange', marker='o', s=15, label="Optimization (distribution)")
line3 = axes[0].scatter(df_zp['mean'], df_popt_samp['mean'], color='red', marker='o', s=15, label="Optimization (sample)")
# Set labels and limits
axes[0].set_xlabel("Reported mean zBMI", fontsize = 18)
axes[0].set_ylabel("Estimated mean zBMI", fontsize = 18)
axes[0].set_xlim(-0.25, 1.75)
axes[0].set_ylim(-0.5, 2.5)

# Increase tick label font size for both x and y axes
axes[0].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[0].legend(handles=[line3, line2],loc="upper left", fontsize = 16)

## PLOT 2
                      
# Plotting
line1 = axes[1].plot(df_zp['SD'], df_zp['SD'], c='black', marker='', linestyle='-', label="_nolegend_")
line2 = axes[1].scatter(df_zp['SD'], df_popt_dist['SD'], color='orange', marker='o', s=15, label="Optimization (distribution)")
line3 = axes[1].scatter(df_zp['SD'], df_popt_samp['SD'], color='red', marker='o', s=15, label="Optimization (sample)")

# Set labels and limits
axes[1].set_xlabel("Reported SD zBMI", fontsize = 18)
axes[1].set_ylabel("Estimated SD zBMI", fontsize = 18)
axes[1].set_xlim(0.2, 2.3)
axes[1].set_ylim(0.2, 2.3)

# Increase tick label font size for both x and y axes

axes[1].tick_params(axis='both', which='major', labelsize=16)

# Add legend
#plt.legend(loc="upper left", bbox_to_anchor=(-0.25, 2.2), title='Legend')
axes[1].legend(handles=[line3, line2],loc="upper left", fontsize = 16)


# Adjust layout to prevent overlapping
plt.tight_layout()

# Save the plot to a file (e.g., PNG format)
#plt.savefig('\\Supplement\\App-comp-opt-perc.png', dpi=300)

# Show the plot
#plt.show()
#display(fig)
